# %%
def fun() :

# %%
def func_1(a) :
    return a ** a

def func_2(a) :
    return func_1(a) * func_1(a)

print(func_2(2))
# Out:
# 16

# %%
y = 2 + 3 * 5.
print(y)
# Out:
# 17.0

# %%
print(1 // 2 * 3)
# Out:
# 0

# %%
y = 2 + 3 * 5
print(y)
# Out:
# 17

# %%
dictionary = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dictionary['one']

for k in range (len(dictionary)):
    v = dictionary[v]

print(v)
# Out:
# two

# %%
def fun(inp=2, out=3):
    return inp * out
print(fun(out=2))
# Out:
# 4

# %%
def fun(x, y, z):
    return x + 2 * y + 3 * z
print(fun(0, z=1, y=3))
# Out:
# 9

# %%
def func(a, b):
    return a ** a

print(func(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/1256780465.py in <module>
#       2     return a ** a
#       3
# ----> 4 print(func(2))
#
# TypeError: func() missing 1 required positional argument: 'b'

# %%
def fun(x):
    x += 1
    return x

x = 2
x = fun(x + 1)
print(x)
# Out:
# 4

# %%
def fun(x):
    global y
    y = x * x
    return y

fun(2)
print(y)
# Out:
# 4

# %%
def f(x):
    if x == 0:
        return 0
    return x + f(x - 1)

print(f(3))
# Out:
# 6

# %%
class A:
    def __init__(self):
        pass
    def f(self):
        return 1
    def g():
        return self.f()
a = A()
print(a.g())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-b026fde42ffc> in <module>
#       7         return self.f()
#       8 a = A()
# ----> 9 print(a.g())
#
# TypeError: g() takes 0 positional arguments but 1 was given

# %%
print(len([i for i in range(0, -2)]))
# Out:
# 0

# %%
import calendar
c = calendar.Calendar(calendar.SUNDAY)
for weekday in c.iterweekdays():
    print(weekday, end=" ")
# Out:
# 6 0 1 2 3 4 5

# %%
i = 4
while i > 0:
    i -= 2
    print("*")
    if i == 2:
        break
else:
    print("*")
# Out:
# *

# %%
my_string = 'abcdef'
def fun(s):
    del s[2]
    return s
print(fun(my_string))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-b2e236d460cf> in <module>
#       3     del s[2]
#       4     return s
# ----> 5 print(fun(my_string))
#
# <ipython-input-9-b2e236d460cf> in fun(s)
#       1 my_string = 'abcdef'
#       2 def fun(s):
# ----> 3     del s[2]
#       4     return s
#       5 print(fun(my_string))
#
# TypeError: 'str' object doesn't support item deletion

# %%
from datetime import datetime
datetime = datetime(2019, 11, 27, 11, 27, 22)
print(datetime.strftime('%y/%m/%d %H:%M:%S'))
# Out:
# 19/11/27 11:27:22

# %%
def a(x):
    def b():
        return x + x
    return b
x = a('x')
y = a('')
print(x() + y())
# Out:
# xx

# %%
from datetime import timedelta
delta = timedelta(weeks = 1, days = 7, hours = 11)
print(delta)
# Out:
# 14 days, 11:00:00

# %%
t = (1, )
t = t[0] + t[0]
print(t)
# Out:
# 2

# %%
try:
    raise Exception
except:
    print("c")
except BaseException:
    print("a")
except Exception:
    print("b")
# Out:
#   File "<ipython-input-15-1819aa442c4a>", line 5
#     except BaseException:
#                      ^
# SyntaxError: default 'except:' must be last

# %%
x = """
"""
print(len(x))
# Out:
# 1

# %%
v = 1 + 1 // 2 + 1 / 2 + 2
print (v)
# Out:
# 3.5

# %%
print(__name__)
# Out:
# __main__

# %%
x = 16
while x > 0:
    print('x', end='')
    x //= 2
# Out:
# xxxxx

# %%
def fun(x):
    return 1 if x % 2 != 0 else 2
print(fun(fun(1)))
# Out:
# 1

# %%
z = 2
y = 1
x = y < z or z > y and y > z or z < y
print (x)
# Out:
# True

# %%
class X:
    pass
class Y(X):
    pass
class Z(Y):
    pass
x = X()
z = Z()
print(isinstance(x, Z), isinstance(z, X))
# Out:
# False True

# %%
class Class:
    def __init__(self):
        pass
object = Class(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a0c6ca211487> in <module>
#       2     def __init__(self):
#       3         pass
# ----> 4 object = Class(None)
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
class A:
    def __init__(self, name):
        self.name = name
a = A("class")
print(a)
# Out:
# <__main__.A object at 0x7fdce8c65690>

# %%
class A:
    pass
class B:
    pass
class C(A,B):
    pass
print(issubclass(C,A) and issubclass(C,B))
# Out:
# True

# %%
x,y,z = 3, 2, 1
z, y, x = x, y, z
print(x,y,z)
# Out:
# 1 2 3

# %%
class A:
    A = 1
    def __init__(self):
        self.a = 0
print(hasattr(A, 'A'))
# Out:
# True

# %%
a = True
b = False
a = a or b
b = a and b
a = a or b
print (a, b)
# Out:
# True False

# %%
my_list = [[c for c in range (r)] for r in range(3)]
for element in my_list:
    if len(element) < 2:
        print('x')
# Out:
# x
# x

# %%
x = "\"
print(len(x))
# Out:
#   File "<ipython-input-36-5c96d8537c0f>", line 1
#     x = "\"
#            ^
# SyntaxError: EOL while scanning string literal

# %%
import os
os.makedirs('pictures/thumbnails')
os.rmdir('pictures')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/3325999153.py in <module>
#       1 import os
# ----> 2 os.makedirs('pictures/thumbnails')
#       3 os.rmdir('pictures')
#
# ~\Programs\Python\Python39\lib\os.py in makedirs(name, mode, exist_ok)
#     223             return
#     224     try:
# --> 225         mkdir(name, mode)
#     226     except OSError:
#     227         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'pictures/thumbnails'

# %%
y = input()
x = input()
print(x + y)
# Out:
# 65

# %%
class A:
    def __init__(self, v):
        self._a = v + 1
a = A(0)
print(a._a)
# Out:
# 1

# %%
1 // 2 * 3
# Out:
# 0

# %%
x = int(input())
y = int(input())
x = x // y
y = y // x
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/1786061320.py in <module>
#       2 y = int(input())
#       3 x = x // y
# ----> 4 y = y // x
#
# ZeroDivisionError: integer division or modulo by zero

# %%
x = int(input())
y = int(input())
x = x / y
y = y / x
print(y)
# Out:
# 8.0

# %%
x = input()
y = int(input())
print( x * y)
# Out:
# 333333

# %%
True = "test"
TRUE = "test"
true = "test"
and = "test"

# %%
print (1/1)
# Out:
# 1.0

# %%
print(20.12E8)
print(20.12*10^8)
# Out:
# 2012000000.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/2456375344.py in <module>
#       1 print(20.12E8)
# ----> 2 print(20.12*10^8)
#
# TypeError: unsupported operand type(s) for ^: 'float' and 'int'

# %%
y = 2 + 3 * 5
print(y)
# Out:
# 17

# %%
x = 1
y = 2
z = x
x = y
y = z
print(x,y)
# Out:
# 2 1

# %%
x = int(input())
y = int(input())

print(x + y)
# Out:
# 6

# %%
x = input()
y = input()

print(x + y)
# Out:
# 24

# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5

# %%
x = int(input())
y = int(input())

x = x // y
y = y // x
print(y)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/3180610977.py in <module>
#       3
#       4 x = x // y
# ----> 5 y = y // x
#       6 print(y)
#       7
#
# ZeroDivisionError: integer division or modulo by zero

# %%
x = int(input())
y = int(input())

x = x % y
x = x % y
y = y % x

print(y)
# Out:
# 1

# %%
var = 0
while var < 6:
    var += 1
    if var % 2 == 0 :
        continue
    print("#")
# Out:
# #
# #
# #

# %%
i = 0
while i <= 3 :
    i += 2
    print("*")
# Out:
# *
# *

# %%
vals = [0, 1, 2]
vals.insert(0, 1)
del vals[1]
print(vals)
# Out:
# [1, 1, 2]

# %%
my_list = [1,2,3]
for v in range(len(my_list)):
    my_list.insert(1, my_list[v])
print(my_list)
# Out:
# [1, 1, 1, 1, 2, 3]

# %%
t = [[3-i for i in range (3)] for j in range (3)]
s = 0
for i in range(3) :
    s += t[i][i]
print(s)
# Out:
# 6

# %%
my_list = [3,1,-2]
print(my_list[my_list[-1]])
# Out:
# 1

# %%
for i in range(1):
    print("#")
else:
    print("#")
# Out:
# #
# #

# %%
i = 0
while i <= 5 :
    i += 1
    if i % 2 == 0:
        break
    print("*")
# Out:
# *

# %%
my_list_1 = [1,2,3]
my_list_2 = []
for v in my_list_1:
    my_list_2.insert(0, v)
print(my_list_2)
# Out:
# [3, 2, 1]

# %%
nums = [1, 2, 3]
vals = nums[-1:-2]
print(nums)
print(vals)
# Out:
# [1, 2, 3]
# []

# %%
z = 10
y = 0
x = y < z and z > y or y > z and z < y
print(x)
# Out:
# True

# %%
my_list = [[0, 1, 2, 3] for i in range(2)]
print(my_list[2][0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/1045557187.py in <module>
#       1 my_list = [[0, 1, 2, 3] for i in range(2)]
# ----> 2 print(my_list[2][0])
#
# IndexError: list index out of range

# %%
vals = [0, 1, 2]
vals[0], vals[2] = vals[2], vals[0]
print(vals)
# Out:
# [2, 1, 0]

# %%
a = 1
b = 0
c = a & b
d = a | b
e = a ^ b
print(c + d + d)
# Out:
# 2

# %%
var = 1
while var < 10:
    print("#")
    var = var << 1
# Out:
# #
# #
# #
# #

# %%
my_list = [i for i in range(-1,2)]
print(my_list)
# Out:
# [-1, 0, 1]

# %%
nums = [1, 2 ,3]
vals = nums
del vals[1:2]
print (nums)
print (vals)
# Out:
# [1, 3]
# [1, 3]

# %%
x = 1
x = x == x
print(x)
# Out:
# True

# %%
my_list = [1, 2, 3, 4]
print(my_list[-3:-2])
# Out:
# [2]

# %%
dictionary = {}
my_list = ['a', 'b', 'c', 'd']
for i in range (len(my_list) - 1):
    dictionary[my_list[i]] = (my_list[i], )

for i in sorted(dictionary.keys()):
    k = dictionary[i]
    print(k[0])
# Out:
# a
# b
# c

# %%
def function(x=0):
    return x
print(function())
# Out:
# 0

# %%
def function(a=0, b=0):
    return a,b
print(function())
# Out:
# (0, 0)

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return
print(fun(fun(2)) +1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/3915922483.py in <module>
#       4     else:
#       5         return
# ----> 6 print(fun(fun(2)) +1)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
my_list = ['Mary', 'had', 'a', 'little', 'lamp']

def my_list(my_list):
    del my_list[3]
    my_list[3] = 'ram'

print(my_list(my_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/625042890.py in <module>
#       5     my_list[3] = 'ram'
#       6
# ----> 7 print(my_list(my_list))
#
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/625042890.py in my_list(my_list)
#       2
#       3 def my_list(my_list):
# ----> 4     del my_list[3]
#       5     my_list[3] = 'ram'
#       6
#
# TypeError: 'function' object does not support item deletion

# %%
x = None
print(x)
if x == None:
    print ("yes")
# Out:
# None
# yes

# %%
my_tuple[1] = my_tuple[1] + my_tuple[0]
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11024/3377915090.py in <module>
# ----> 1 my_tuple[1] = my_tuple[1] + my_tuple[0]
#       2 print(my_tuple)
#
# NameError: name 'my_tuple' is not defined

# %%
def any():
    print(var + 1, end='')

var = 1
any()
print(var)
# Out:
# 21

# %%
tup = (1, 2, 4, 8)
tup = tup[1:-1]
tup = tup[0]
print(tup)
# Out:
# 2

# %%
print("hello")
# Out:
# hello

# %%
x = input()
print(x)
# Out:
# 23

# %%
dictionary = {'one':'two', 'three' : 'one', 'two': 'three'}
v = dictionary['one']
for k in range(len(dictionary)):
    v = dictionary[v]

print(v)
# Out:
# two

# %%
def fun(x, y, z):
    return x + 2 * y + 3 * Z

print(fun(0, z=1, y=3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/65212827.py in <module>
#       2     return x + 2 * y + 3 * Z
#       3
# ----> 4 print(fun(0, z=1, y=3))
#
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/65212827.py in fun(x, y, z)
#       1 def fun(x, y, z):
# ----> 2     return x + 2 * y + 3 * Z
#       3
#       4 print(fun(0, z=1, y=3))
#
# NameError: name 'Z' is not defined

# %%
def f(x):
    if x == 0:
        return 0
    return x + f(x-1)

print(f(3))
# Out:
# 6

# %%
def any():
    print(var + 1, end='')

var = 1
any()
print(var)
# Out:
# 21

# %%
my_list = ['Mary', 'had', 'little', 'lamp']
def my_list(my_list):
    del my_list[3]
    my_list[3] = 'ram'
print(my_list(my_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/750981237.py in <module>
#       3     del my_list[3]
#       4     my_list[3] = 'ram'
# ----> 5 print(my_list(my_list))
#
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/750981237.py in my_list(my_list)
#       1 my_list = ['Mary', 'had', 'little', 'lamp']
#       2 def my_list(my_list):
# ----> 3     del my_list[3]
#       4     my_list[3] = 'ram'
#       5 print(my_list(my_list))
#
# TypeError: 'function' object does not support item deletion

# %%
def fun(x):
    global y
    y = x * x
    return y
fun(2)
print(y)
# Out:
# 4

# %%
v = 3
if v == None :
    print('yes')

# %%
def func_1(a):
    return a ** a
def func_2(a):
    return func_1(a) * func_1(a)
print(func_2(2))
# Out:
# 16

# %%
tup = (1, 2, 4, 8)
tup = tup[1:-1]
tup = tup[0]
print(tup)
# Out:
# 2

# %%
def fun(inp=2, out=3):
    return inp * out

print(fun(out=2))
# Out:
# 4

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return
print(fun(fun(2)) + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/2695987589.py in <module>
#       4     else:
#       5         return
# ----> 6 print(fun(fun(2)) + 1)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
function fun()
return 'sdfs'
# Out:
#   File "C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/1384553302.py", line 1
#     function fun()
#              ^
# SyntaxError: invalid syntax

# %%
def func(a, b):
    return a ** a
print(func(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/3520589447.py in <module>
#       1 def func(a, b):
#       2     return a ** a
# ----> 3 print(func(2))
#
# TypeError: func() missing 1 required positional argument: 'b'

# %%
def fun(x):
    x += 1
    return x

x = 2
x = fun(x + 1)
print(x)
# Out:
# 4

# %%
my_tuple = (1,3,4)
my_tuple[1] = my_tuple[1] + my_tuple[0]
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/4257951162.py in <module>
#       1 my_tuple = (1,3,4)
# ----> 2 my_tuple[1] = my_tuple[1] + my_tuple[0]
#       3 print(my_tuple)
#
# TypeError: 'tuple' object does not support item assignment

# %%
nums = [1, 2, 3]
vals = nums
del vals[:]
print(nums, vals)
# Out:
# [] []

# %%
in = 2
for = 2
print = 2
In = 3

# %%
x = int(input())
y = int(input())
x = x % y
x = x % y
y = y % x
print(y)
# Out:
# 0

# %%
dct = {}
dct['1'] = (1,2)
dct['2'] = (2,1)
for x in dct.keys():
    print(dct[x][1], end="")
# Out:
# 21

# %%
def func(a, b):
    return b ** a

print(func(b=2, 2))
# Out:
#   File "C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_12708/3814376203.py", line 4
#     print(func(b=2, 2))
#                      ^
# SyntaxError: positional argument follows keyword argument

# %%
tup = (1, 2, 4, 8)
tup = tup[-2:-1]
tup = tup[-1]
print(tup)
# Out:
# 4

# %%
y = input()
x = input()
print(x + y)
# Out:
# 63

# %%
z = 0
y = 10
x = y < z and z > y or y > z and z < y
print(x)
# Out:
# True

# %%
def fun(x, y):
    if x == y:
        return x
    else:
        return fun(x, y-1)
print(fun(0,3))
# Out:
# 0

# %%
x = float(input())
y = float(input())
print(y ** (1 / x))
# Out:
# 2.0

# %%
x = 1 // 5 + 1 / 5
print(x)
# Out:
# 0.2

# %%
print("*")
# Out:
# *

# %%
dictionary = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dictionary['three']

for k in range (len(dictionary)):
    v = dictionary[v]

print(v)
# Out:
# one

# %%
nums = [1, 2, 3]
vals = nums
print(nums)
print(vals)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
print("a", "b", "c", sep="sep")
# Out:
# asepbsepc

# %%
dd = {"1": "0", "0": "1"}
for x in dd.vals():
    print(x, end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_4724/2633924205.py in <module>
#       1 dd = {"1": "0", "0": "1"}
# ----> 2 for x in dd.vals():
#       3     print(x, end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
my_list = [1, 2]

for v in range(2):
    my_list.insert(-1, my_list[v])

print(my_list)
# Out:
# [1, 1, 1, 2]

# %%
def fun(a, b, c=0):
    print(a, b, c)
fun(b=0, a=0)
fun(0,1,2)
fun()
fun(b=1)
# Out:
# 0 0 0
# 0 1 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_4724/1344090001.py in <module>
#       3 fun(b=0, a=0)
#       4 fun(0,1,2)
# ----> 5 fun()
#       6 fun(b=1)
#
# TypeError: fun() missing 2 required positional arguments: 'a' and 'b'

# %%
def fun(inp=2, out=3):
    return inp * out

print(fun(out=2))
# Out:
# 4

# %%
x = 1
y = 2
x, y, z = x, x, y
z, y, z = x, y, z
print(x, y, z)
# Out:
# 1 1 2

# %%
a = 1
b = 0
a = a ^ b
b = a ^ b
a = a ^ b
print(a, b)
# Out:
# 0 1

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return 2

print(fun(fun(2)))
# Out:
# 2

# %%
print( 1 // 2)
# Out:
# 0

# %%
lst = [[x for x in range(3)] for y in range (3) ]

for r in range(3):
    for c in range(3):
        if lst[r][c] % 2 != 0:
            print("#")
# Out:
# #
# #
# #

# %%
def function_1(a) :
    return None

def function_2(a) :
    return function_1(a) * function_1(a)

print(function_2(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_4724/1576823739.py in <module>
#       5     return function_1(a) * function_1(a)
#       6
# ----> 7 print(function_2(2))
#
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_4724/1576823739.py in function_2(a)
#       3
#       4 def function_2(a) :
# ----> 5     return function_1(a) * function_1(a)
#       6
#       7 print(function_2(2))
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
lst = [ i for i in range (-1, -2)]
print (lst)
# Out:
# []

# %%
my_list = [ x * x for i in range (5)]
def fun(my_list):
    del my_list[my_list[2]]
    return my_list


print (fun(my_list))
# Out:
# [1, 1, 1, 1]

# %%
i = 5
while i>0:
    i= 1 // 2
    if i % 2 == 0:
        break
else:
        i += 1
print(i)
# Out:
# 0

# %%
for i in range (1,3):
    print("*", end="")
else:
    print("*")
# Out:
# ***

# %%
print(.3423e2)
print(3423e-2)
# Out:
# 34.23
# 34.23

# %%
a = "aaaaaaaaa"
print(len(a))
a = a[1:-2]
print (a)
print(len(a))
# Out:
# 9
# aaaaaa
# 6

# %%
lst = [1,2,3,4]
lst = lst[-3:-2]
lst = lst[-1]
print(lst)
# Out:
# 2

# %%
s = 'abc'
for i in len(s):
    s[i] = s[i].upper()
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_10356/3331557838.py in <module>
#       1 s = 'abc'
# ----> 2 for i in len(s):
#       3     s[i] = s[i].upper()
#       4 print(s)
#
# TypeError: 'int' object is not iterable

# %%
list1 = [False for i in range (1,10)]
list2 = list1 [-1:1:-1]
print(list2)
# Out:
# [False, False, False, False, False, False, False]

# %%
For = 1
true = 2
print(For, true)
# Out:
# 1 2

# %%
s = '*****'
s = s - s[2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_10356/3564660025.py in <module>
#       1 s = '*****'
# ----> 2 s = s - s[2]
#       3 print(s)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
List1 = "dont thik twice, do it".split(',')
print(List1)
# Out:
# ['dont thik twice', ' do it']

# %%
x = 'x'
print(chr(ord(x)) == x)
print(ord(chr(x)) == x)
# Out:
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_10356/1202579503.py in <module>
#       1 x = 'x'
#       2 print(chr(ord(x)) == x)
# ----> 3 print(ord(chr(x)) == x)
#
# TypeError: an integer is required (got type str)

# %%
s = "the catcher"
print(s.split())
print(s.split("\~"))
# Out:
# ['the', 'catcher']
# ['the catcher']

# %%
print(sorted("python"))
print("python".index("th"))
print("python".sort())
# Out:
# ['h', 'n', 'o', 'p', 't', 'y']
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11636/849756186.py in <module>
#       1 print(sorted("python"))
#       2 print("python".index("th"))
# ----> 3 print("python".sort())
#
# AttributeError: 'str' object has no attribute 'sort'

# %%
try:
    print("5"/0)
except ArithmeticError:
    print("arith")
except ZeroDivisionError:
    print("zero")
except:
    print("some")
# Out:
# some

# %%
x = '\''
print(len(x))
# Out:
# 1

# %%
print(float("1, 3"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_11636/1976150975.py in <module>
# ----> 1 print(float("1, 3"))
#
# ValueError: could not convert string to float: '1, 3'

# %%
print('Mike' > "Mikey")
# Out:
# False

# %%
print(chr(ord('z') - 2))
# Out:
# x

# %%
print(ord('c') - ord('a'))
# Out:
# 2

# %%
for i in range (1, 3):
    print("*", end="")
else:
    print("*")
# Out:
# ***

# %%
s = "1234567"
print(s[1:-2])
# Out:
# 2345

# %%
lst = [1,2,3,4]
print (lst)
lst = lst [-3:-2]
print (lst)
lst = lst [-1]
print (lst)
# Out:
# [1, 2, 3, 4]
# [2]
# 2

# %%
v = 2
print(v >> 1)
# Out:
# 1

# %%
print("test")
# Out:
# test

# %%
print("Hello World")
# Out:
# Hello World

# %%
class A:
    def __init__(self):
        pass
a = A(1)
print(hasattr(a, 'A'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_2144/2630956591.py in <module>
#       2     def __init__(self):
#       3         pass
# ----> 4 a = A(1)
#       5 print(hasattr(a, 'A'))
#
# TypeError: __init__() takes 1 positional argument but 2 were given

# %%
class A:
    A = 1
print(hasattr(A,'A'))
# Out:
# True

# %%
class A:
    def __init__(self):
        self.a = 1
class B(A):
    def __init__(self):
        A.__init__(self)
        self.b = 2

# %%
class A:
    X = 0
    def __init__(self,v = 0):
        self.Y = v
        A.X += v

a = A()
b = A(1)
c = A(2)
print(c.X)
# Out:
# 3

# %%
class Ex(Exception):
    def __init__(self,msg):
        Exception.__init__(self,msg)
        self.args = (msg,)

try:
    raise Ex('ex')
except Ex as e:
    print(e)
except Exception as e:
    print(e)
# Out:
# ex

# %%
class A:
    def __init__(self,v = 1):
        self.v = v

    def set(self,v):
        self.v = v
        return v

a = A()
print(a.set(a.v + 1))
# Out:
# 2

# %%
try:
    raise Exception(1,2,3)
except Exception as e:
    print(len(e.args))
# Out:
# 3

# %%
class A:
    pass
class B(A):
    pass
class C(B):
    pass

print(issubclass(C,A))
# Out:
# True

# %%
class A:
    def __str__(self):
        return 'a'

class B:
    def __str__(self):
        return 'b'

class C(A, B):
    pass

o = C()
print(o)
# Out:
# a

# %%
class A:
    def __str__(self):
        return 'a'
class B(A):
    def __str__(self):
        return 'b'
class C(B) :
    pass

o = C()
print(o)
# Out:
# b

# %%
class A:
    v = 2

class B(A):
    v = 1

class C(B):
    pass

o = C()
print(o.v)
# Out:
# 1

# %%
class Class:
    def __init__(self):
        pass
object = Class()

print(object)
# Out:
# <__main__.Class object at 0x000001CF240E83D0>

# %%
def f(x):
    try:
        x = x / x
    except:
        print("a", end='')
    else:
        print("b", end='')
    finally:
        print("c", end='')

f(1)
f(0)
# Out:
# bcac

# %%
class A:
    def a(self):
        print('a')

class B:
    def a(self):
        print('b')

class C(B,A):
    def c(self):
        self.a()
o = C()
o.c()
# Out:
# b

# %%
class A:
    def __init__(self,v):
        self.__a = v + 1

a = A(0)
print(a.__a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_2144/2697971166.py in <module>
#       4
#       5 a = A(0)
# ----> 6 print(a.__a)
#
# AttributeError: 'A' object has no attribute '__a'
